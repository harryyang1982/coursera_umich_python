# %%
import numpy as np
import pandas as pd

# %%
a = np.arange(0, 11)

# %%
np.mean(a)
# Out:
# 5.0

# %%
url = "https://d3c33hcgiwev3.cloudfront.net/YtT9NroBEemddAqBQMk_og_f682394f0a2542cea617efa59089ab2b_Cartwheeldata.csv?Expires=1656028800&Signature=U1k0S7K2ov-zrlh52HngWs61YtYrMnBW-ZnKAT7BQ7s~P3MyjAzE6XJkVSq6dyMoOGWFyZn-8V98pNa8i5Uq~wMWMaX43tLeRA3us7WJ7RVs4VijDBTpDpE~bkxDmOlbIlXsH199bQMaXacwH0KcxlYjIKQB0nmWp78pi9cvois_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A"

# %%
df = pd.read_csv(url)

# %%
df.loc[:, 'CWDistance']
# Out:
# 0      79
# 1      70
# 2      85
# 3      87
# 4      72
# 5      81
# 6     107
# 7      98
# 8     106
# 9      65
# 10     96
# 11     79
# 12     92
# 13     66
# 14     72
# 15    115
# 16     90
# 17     74
# 18     64
# 19     85
# 20     66
# 21    101
# 22     82
# 23     63
# 24     67
# Name: CWDistance, dtype: int64

# %%
df["CWDistance"]
# Out:
# 0      79
# 1      70
# 2      85
# 3      87
# 4      72
# 5      81
# 6     107
# 7      98
# 8     106
# 9      65
# 10     96
# 11     79
# 12     92
# 13     66
# 14     72
# 15    115
# 16     90
# 17     74
# 18     64
# 19     85
# 20     66
# 21    101
# 22     82
# 23     63
# 24     67
# Name: CWDistance, dtype: int64

# %%
df.loc[:9, ["CWDistance"]]
# Out:
#    CWDistance
# 0          79
# 1          70
# 2          85
# 3          87
# 4          72
# 5          81
# 6         107
# 7          98
# 8         106
# 9          65

# %%
df.iloc[:4]
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10

# %%
df.iloc[1:5, 2:4]
# Out:
#   Gender  GenderGroup
# 1      F            1
# 2      F            1
# 3      F            1
# 4      M            2

# %%
df.iloc[1:5, ["Gender", "GenderGroup"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/seunghoonyang/Documents/python/coursera_umich_python/libraries_data_management.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/seunghoonyang/Documents/python/coursera_umich_python/libraries_data_management.ipynb#ch0000010?line=0'>1</a> df.iloc[1:5, ["Gender", "GenderGroup"]]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
# ...

# %%
df.dtypes
# Out:
# ID                 int64
# Age                int64
# Gender            object
# GenderGroup        int64
# Glasses           object
# GlassesGroup       int64
# Height           float64
# Wingspan         float64
# CWDistance         int64
# Complete          object
# CompleteGroup      int64
# Score              int64
# dtype: object

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.GenderGroup.unique()
# Out:
# array([1, 2])

# %%
df.groupby(['Gender', 'GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...
